# %% [markdown]
# <a href="https://colab.research.google.com/github/Mustafa4564/DS_LAB/blob/main/Testcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def check_even_odd(number):
    if number % 2 == 0:
        return f"{number} is an even number."
    else:
        return f"{number} is an odd number."

# Test with some numbers
print(check_even_odd(4))
print(check_even_odd(7))
print(check_even_odd(0))
print(check_even_odd(101))
# Out:
# 4 is an even number.
# 7 is an odd number.
# 0 is an even number.
# 101 is an odd number.
